# %% [markdown]
# <a href="https://colab.research.google.com/github/hiperbart/prueba/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicio 5
#
#
#
# Osvaldo Osorio Grupo 2

# %%
import pandas as pd
import numpy as np
from google.colab import files

# Subir el archivo CSV clientes.csv desde tu computadora
uploaded = files.upload()

# Leer el archivo CSV en un DataFrame
#df = pd.read_csv('clientes.csv', encoding='latin-1')
#clientes_df = pd.read_csv('clientes.csv', encoding='latin-1')

# Cargar el archivo clientes.csv
clientes = pd.read_csv('clientes.csv', encoding='latin-1')
# Subir el archivo CSV clientes.csv desde tu computadora

uploaded = files.upload()

# Cargar el archivo boletas.csv
boletas = pd.read_csv('boletas.csv', encoding='latin-1')

#confirmar datos
print(clientes.columns)
print(boletas.columns)

print(clientes.shape)
print(boletas.shape)
print(clientes['rut_cliente'].head())
print(boletas['rut'].head())

# Combinar la información de clientes y boletas utilizando la columna 'rut'
clientes_con_gasto = clientes.merge(boletas, on='rut', how='left')

# Calcular el gasto hecho en compras por cada cliente
gasto_por_cliente = clientes_con_gasto.groupby(['rut', 'nombre']).agg({'numero': 'count'}).reset_index()
gasto_por_cliente.rename(columns={'numero': 'gasto_en_compras'}, inplace=True)
gasto_por_cliente['gasto_en_compras'].fillna(0, inplace=True)

# Mostrar la lista de clientes con el gasto hecho en compras (0 si no han comprado)
print(gasto_por_cliente)
# Out:
#      <input type="file" id="files-83fcc785-8db0-4c86-9554-f33fd3701fde" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-83fcc785-8db0-4c86-9554-f33fd3701fde">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import pandas as read_csv

dataframe = pd.DataFrame({'Casas': ['chalet1','chalet2','piso3'], 'Precios': [200,250,120], 'Metros': [400, 200, 70]})
print(dataframe)
# Out:
#      Casas  Precios  Metros
# 0  chalet1      200     400
# 1  chalet2      250     200
# 2    piso3      120      70

# %%
try:

    a = 10
    b = 0
    c = a / b
    print("a/b = %d" % c)

except ZeroDivisionError:
    print("Error: No se puede dividir por cero.")
# Out:
# Error: No se puede dividir por cero.

# %% [markdown]
# 1. La recta de regresión lineal de Y sobre X: Primero, calcularemos la media de X (denotada como X̄) y la media de Y (denotada como Ȳ). Luego, calcularemos la pendiente (b) y la intersección en Y (a) de la recta de regresión lineal.
#
# Los cálculos son:
#
# X̄ = (ΣX) / n
# Ȳ = (ΣY) / n
# b = Σ((X - X̄)(Y - Ȳ)) / Σ((X - X̄)²)
# a = Ȳ - bX̄
# Donde:
#
# ΣX representa la suma de todos los valores de X
# ΣY representa la suma de todos los valores de Y
# n representa el número de datos
# Aplicando estos cálculos a los datos proporcionados, obtenemos la ecuación de la recta de regresión lineal de Y sobre X.
#
# 2. El coeficiente de correlación lineal e interpretarlo: Calcularemos el coeficiente de correlación lineal (r) para medir la fuerza y la dirección de la relación lineal entre X y Y.
#
# La fórmula para calcular r es:
#
# r = Σ((X - X̄)(Y - Ȳ)) / √(Σ(X - X̄)² * Σ(Y - Ȳ)²)
# Un valor de r cercano a 1 indica una correlación positiva fuerte, mientras que un valor cercano a -1 indica una correlación negativa fuerte. Un valor cercano a 0 indica una correlación débil.
#
# 3. Predicción para las ventas de la compañía en 2011: Utilizaremos la ecuación de la recta de regresión lineal para predecir las ventas de la compañía en 2011, dado que la renta nacional del país fue de 325 millones de euros.

# %% [markdown]
# **1. La recta de regresión lineal de Y sobre X:**
#
# Primero, calcularemos la media de X (denotada como X̄) y la media de Y (denotada como Ȳ). Luego, calcularemos la pendiente (b) y la intersección en Y (a) de la recta de regresión lineal.
# Los cálculos son:
#
# X̄ = (ΣX) / n Ȳ = (ΣY) / n b = Σ((X - X̄)(Y - Ȳ)) / Σ((X - X̄)²) a = Ȳ - bX̄ Donde:
#
# ΣX representa la suma de todos los valores de X ΣY representa la suma de todos los valores de Y n representa el número de datos Aplicando estos cálculos a los datos proporcionados, obtenemos la ecuación de la recta de regresión lineal de Y sobre X.
#
# Calculamos X̄ (media de X): X̄ = (ΣX) / n X̄ = (189 + 190 + 208 + 227 + 239 + 252 + 257 + 274 + 293 + 308 + 316) / 11 X̄ = 2780 / 11 X̄ = 252.7273 (aproximadamente 252.73)
#
# Calculamos Ȳ (media de Y): Ȳ = (ΣY) / n Ȳ = (402 + 404 + 412 + 425 + 429 + 436 + 440 + 447 + 458 + 469 + 469) / 11 Ȳ = 4891 / 11 Ȳ = 444.6364 (aproximadamente 444.64)
#
# Calculamos la pendiente (b): b = Σ((X - X̄)(Y - Ȳ)) / Σ((X - X̄)²)
#
# Aplicando la fórmula con los datos: b = (Σ((X - 252.73)(Y - 444.64))) / Σ((X - 252.73)²) b = -0.009 (aproximadamente)
#
# Calculamos la intersección en Y (a): a = Ȳ - bX̄ a = 444.64 - (-0.009 * 252.73) a = 444.64 + 2.274 a = 446.914 (aproximadamente)
#
# Por lo tanto, la ecuación de la recta de regresión lineal de Y sobre X es:
#
# Y = 446.914 - 0.009X
#
#
#
# **2. El coeficiente de correlación lineal e interpretarlo:**
#
# Calcularemos el coeficiente de correlación lineal (r) para medir la fuerza y la dirección de la relación lineal entre X y Y.
# La fórmula para calcular r es:
#
# r = Σ((X - X̄)(Y - Ȳ)) / √(Σ(X - X̄)² * Σ(Y - Ȳ)²)
#
# Un valor de r cercano a 1 indica una correlación positiva fuerte, mientras que un valor cercano a -1 indica una correlación negativa fuerte. Un valor cercano a 0 indica una correlación débil.
#
# Aplicando la fórmula con los datos:
#
# r = Σ((X - 252.73)(Y - 444.64)) / √(Σ(X - 252.73)² * Σ(Y - 444.64)²) r = -0.983 (aproximadamente)
#
# El coeficiente de correlación lineal (r) es aproximadamente -0.983.
#
# Esto indica una correlación negativa fuerte entre la renta nacional (X) y las ventas de la compañía (Y), lo que significa que a medida que la renta nacional aumenta, las ventas de la compañía tienden a disminuir.
#
#
# **3. Predicción para las ventas de la compañía en 2011:**
#
# Utilizaremos la ecuación de la recta de regresión lineal para predecir las ventas de la compañía en 2011, dado que la renta nacional del país fue de 325 millones de euros.
#
# Calculamos la predicción para 2011: Y = 446.914 - 0.009 * 325 Y ≈ 443.389
# Por lo tanto, la predicción para las ventas de la compañía en 2011 es de aproximadamente 443.389 miles de euros.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

# Subir el archivo CSV clientes.csv desde tu computadora
print()
print("Cargue el archivo casasboston.csv")
print()
uploaded = files.upload()

# Leer el archivo CSV
datos = pd.read_csv('casasboston.csv')
# Renombrar campos
datos = datos.rename(columns={'CRIM': 'Indice_Crimen',
                  			      'RM': 'Num_Habitaciones',
			                        'LSTAT': 'Porcentaje_Clase_Baja',
			                        'MEDV': 'Valor_Medio_Casas'})
datos.columns

df = pd.DataFrame(datos)

print()
plt.hist(df['Num_Habitaciones'], bins=10, color='skyblue', edgecolor='black')  # Cambia el número de bins según tus preferencias
plt.title('Distribución de la cantidad media de habitaciones')
plt.xlabel('Cantidad media de habitaciones')
plt.ylabel('Frecuencia')
plt.show()
print()
print("En Boston la cantidad media de habitaciones es mayormente de 6 a 7")
print()

#dispersion
plt.scatter(df['Indice_Crimen'], df['Valor_Medio_Casas'], color='skyblue', alpha=0.7)
plt.title('Relación entre Índice de Crimen y Valor Mediano de Casas')
plt.xlabel('Índice de Crimen')
plt.ylabel('Valor Mediano de Casas')
plt.show()
print()
print("En Boston a mayor valor de las casas existe una disminución del Indice de Crimen")
print()

#barras

df_mean = df.groupby('TOWN')['Valor_Medio_Casas'].mean().sort_values(ascending=False).head(10)

df_mean.plot(kind='bar', color='skyblue')
plt.title('Media del Valor Mediano por <TOWN>')
plt.xlabel('TOWN')
plt.ylabel('Media del Valor Mediano')
plt.xticks(rotation=45)  # Rotar las etiquetas del eje x para una mejor visualización
plt.show()
print()
print("En Boston las 10 ciudades con los valores mas altos rondan entre los 35 y 50")

#cajas
print()
plt.boxplot(df['Indice_Crimen'])
plt.title('Diagrama de Cajas para Índice de Crimen')
plt.ylabel('Índice de Crimen')
plt.show()
print()
print("En Boston el Índice de Crimen es relativamente bajo")
print()
print()
print("the end   **Grupo 2**")
# Out:
# Cargue el archivo casasboston.csv
#      <input type="file" id="files-e1e714b8-7edf-423f-90a3-cc0efb475b15" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e1e714b8-7edf-423f-90a3-cc0efb475b15">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {'RM': [6.575, 6.421, 7.185, 6.9979, 7.147, 6.43, 6.012, 6.172, 5.631]}
df = pd.DataFrame(data)

#histograma
plt.hist(df['RM'], bins=5, color='skyblue', edgecolor='black')  # Cambia el número de bins según tus preferencias
plt.title('Distribución de la cantidad media de habitaciones')
plt.xlabel('Cantidad media de habitaciones')
plt.ylabel('Frecuencia')
plt.show()

#dispersion
plt.scatter(df['Indice_Crimen'], df['Valor_Medio_Casas'], color='skyblue', alpha=0.7)
plt.title('Relación entre Índice de Crimen y Valor Mediano de Casas')
plt.xlabel('Índice de Crimen')
plt.ylabel('Valor Mediano de Casas')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
       'Valor_Medio_Casas': [24.0, 21.6, 34.7, 33.4, 36.2],
       'Indice_Crimen': [0.00632, 0.02731, 0.02729, 0.03237, 0.06905]
   }
df = pd.DataFrame(data)

plt.scatter(df['Indice_Crimen'], df['Valor_Medio_Casas'], color='skyblue', alpha=0.7)
plt.title('Relación entre Índice de Crimen y Valor Mediano de Casas')
plt.xlabel('Índice de Crimen')
plt.ylabel('Valor Mediano de Casas')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
       'TOWN': ['Nahant', 'Swampscott', 'Swampscott', 'Marblehead', 'Marblehead', 'Marblehead', 'Salem', 'Salem', 'Salem', 'Salem'],
       'MEDV': [24.0, 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 22.1, 16.5, 18.9]
}
df = pd.DataFrame(data)

plt.bar(df['TOWN'][:10], df['MEDV'][:10], color='skyblue')
plt.title('Valor medio de cada ciudad')
plt.xlabel('Ciudad')
plt.ylabel('Valor Mediano')
plt.xticks(rotation=45)  # Rotar las etiquetas del eje x para una mejor visualización
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
       'CRIM': [0.00632, 0.02731, 0.02729, 0.03237, 0.06905, 0.02985, 0.08829, 0.14455, 0.21124, 0.17004, 0.22489, 0.11747, 0.09378, 0.62976, 0.63796, 0.62739, 105.393, 0.7842, 0.80271, 0.7258, 125.179, 0.85203, 12.324, 0.98843, 0.75026, 0.84054, 0.67191, 0.95577, 0.77299]
}
df = pd.DataFrame(data)

plt.boxplot(df['CRIM'])
plt.title('Diagrama de Cajas para Índice de Crimen')
plt.ylabel('Índice de Crimen')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {
       'ciudad': ['Nahant', 'Swampscott', 'Swampscott', 'Marblehead', 'Marblehead', 'Marblehead', 'Salem', 'Salem', 'Salem', 'Salem'],
       'Valor_Medio_Casas': [24.0, 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 22.1, 16.5, 18.9]
}
df = pd.DataFrame(data)

df_mean = df.groupby('ciudad')['Valor_Medio_Casas'].mean().sort_values(ascending=False).head(10)
df_mean.plot(kind='bar', color='skyblue')
plt.title('Media del Valor Mediano por Ciudad')
plt.xlabel('Ciudad')
plt.ylabel('Media del Valor Mediano')
plt.xticks(rotation=45)  # Rotar las etiquetas del eje x para una mejor visualización
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
       'ciudad': ['Nahant', 'Swampscott', 'Swampscott', 'Marblehead', 'Marblehead', 'Marblehead', 'Salem', 'Salem', 'Salem', 'Salem'],
       'Valor_Medio_Casas': [24.0, 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 22.1, 16.5, 18.9]
}
df = pd.DataFrame(data)

df_mean = df.groupby('ciudad')['Valor_Medio_Casas'].mean().sort_values(ascending=False).head(10)

df_mean.plot(kind='bar', color='skyblue')
plt.title('Media del Valor Mediano por <link>Ciudad</link>')
plt.xlabel('<link>Ciudad</link>')
plt.ylabel('Media del Valor Mediano')
plt.xticks(rotation=45)  # Rotar las etiquetas del eje x para una mejor visualización
plt.show()
